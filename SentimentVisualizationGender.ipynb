# %%
#!pip install vaderSentiment

# %%
import os, json
import pandas as pd
import regex as re
import numpy as np
import pickle

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import nltk

import warnings
warnings.filterwarnings('ignore')

# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/

# %%
aktuellPickle = 'C:\\Users\\Felix\\github\\privat\\dis25_abgabe\\data\\wpdata\\data\\hundredthousand_wp.pickle'
data = pd.read_pickle(aktuellPickle)
#data = data[:100]

# %%
data
# Out:
#                                          id  \
# 0                ABM35HDPIII6RP4GUI2RWXWOTE
# 1      7f4cc4bc-351a-11e4-9e92-0899b306bbea
# 2      aa34106e-bc85-11e1-8867-ecf6cb7935ef
# 3      27a3bb38-f74a-11e4-9ef4-1bb7ce3b3fb7
# 4      24e0ddf8-1b29-11e3-82ef-a059e54c49d0
# ...                                     ...
# 99995            O4VKXIG34YI6TLDDGALHCFKD7Y
# 99996  2e1725e4-8c9f-11e2-9f54-f3fdd70acad2
# 99997      65834e3da2fe81841adfe38048477458
# 99998      2c54da3cf388fa30372c9a8cfcd6aa5e
# 99999  687f01aa-e687-11e3-8f90-73e071f3d637
#
#                                              article_url  \
# 0      /opinions/the-hollow-compassion-of-trump-wary-...
# 1      https://www.washingtonpost.com/local/u-md-bask...
# 2      https://www.washingtonpost.com/opinions/mitch-...
# 3      https://www.washingtonpost.com/local/local-dig...
# 4      https://www.washingtonpost.com/local/man-sente...
# ...                                                  ...
# 99995  /politics/trumps-ukraine-scandal-may-also-hurt...
# 99996  https://www.washingtonpost.com/local/education...
# 99997  https://www.washingtonpost.com/news/the-switch...
# 99998  https://www.washingtonpost.com/news/recruiting...
# 99999  https://www.washingtonpost.com/entertainment/t...
#
#                                                    title  \
# 0              Trump’s America goes full Charles Dickens
# 1      U-Md. basketball arena is transformed into mak...
# 2      Mitch McConnell: How political disclosure coul...
# 3                             Local digest: May 11, 2015
# 4        Man sentenced to 27 years in Carl Diener murder
# ...                                                  ...
# 99995  Scrutiny over Trump’s Ukraine scandal may also...
# 99996            Georgetown celebrates first Jesuit pope
# 99997   Netflix is raising its prices again. Here’s why.
# 99998  Sophomore wing Taniya Dunn fills it up for SEE...
# 99999       TV highlights: ‘Crossbones’ premieres on NBC
#
#                                  author  published_date     type  \
# 0                          Dana Milbank             NaN      NaN
# 1                            Karen Chen    1.409960e+12  article
# 2                       Mitch McConnell    1.340406e+12  article
# 3      — Michael Smith; — Peter Hermann    1.431294e+12  article
# 4                         Rachel Weiner    1.379001e+12  article
# ...                                 ...             ...      ...
# 99995                        Matt Viser             NaN      NaN
# 99996                     Nick Anderson    1.363266e+12  article
# 99997       Brian Fung; Andrea Peterson    1.444340e+12     blog
# 99998                         Tariq Lee    1.391193e+12     blog
# 99999                     Rachel Lubitz    1.401400e+12  article
#
#                     source                                            content  \
# 0                      NaN  [{'content': 'Opinions', 'mime': 'text/plain',...
# 1      The Washington Post  [{'content': 'Local', 'mime': 'text/plain', 't...
# 2      The Washington Post  [{'content': 'Opinions', 'mime': 'text/plain',...
# 3      The Washington Post  [{'content': 'Local', 'mime': 'text/plain', 't...
# 4      The Washington Post  [{'content': 'Local', 'mime': 'text/plain', 't...
# ...                    ...                                                ...
# 99995                  NaN  [{'content': 'Politics', 'mime': 'text/plain',...
# 99996  The Washington Post  [{'content': 'Education', 'mime': 'text/plain'...
# 99997  The Washington Post  [{'content': 'The Switch', 'mime': 'text/plain...
# 99998  The Washington Post  [{'content': 'AllMetSports', 'mime': 'text/pla...
# 99999  The Washington Post  [{'content': 'TV', 'mime': 'text/plain', 'type...
#
#        publish_date orig-id
# 0               NaN     NaN
# 1               NaN     NaN
# 2               NaN     NaN
# 3               NaN     NaN
# 4               NaN     NaN
# ...             ...     ...
# 99995           NaN     NaN
# 99996           NaN     NaN
# 99997           NaN     NaN
# 99998           NaN     NaN
# 99999           NaN     NaN
#
# [100000 rows x 10 columns]

# %% [markdown]
# ## Enrichment of the DataFrame

# %% [markdown]
# ### Category

# %%
def findCategory(x):
    if re.search('-',x):
        return "other"
    else:
        return x

# %%
def convertURL(predata):
    predata["category"] = predata.apply(lambda row: str(row["article_url"]).split('/')[3] , axis=1)
    predata["category"] = predata.apply(lambda row: findCategory(str(row["category"])) , axis=1)
    return predata

# %% [markdown]
# ### Sentiment Analysis

# %%
def getSentimentScore(predata):
    analyzer = SentimentIntensityAnalyzer()
    cs = []
    for row in range(len(data)):
        cs.append(analyzer.polarity_scores(data['title'].iloc[row])['compound'])
    predata['title_vader_score'] = cs
    predata = predata[(predata[['title_vader_score']] != 0).all(axis=1)].reset_index(drop=True)
    return predata

# %%
def sentiment(vader_score):
    if vader_score >= 0.05 : 
        return("Positive") 
    elif vader_score <= - 0.05 : 
        return("Negative")  
    else : 
        return("Neutral")

# %%
def getSentiment(predata):
    getSentimentScore(predata)
    predata['title_vader_score'] = predata.apply(lambda row: sentiment(row["title_vader_score"]), axis=1)
    return predata

# %% [markdown]
# ### Lenght

# %%
def getLenght(predata):
    predata["word_title"] = predata.apply(lambda row: len(nltk.word_tokenize(str(row["title"]))), axis=1)
    predata["len_title"] = predata.apply(lambda row: len(str(row["title"])), axis=1)
    return predata

# %% [markdown]
# ### agency_communion

# %%
def load_list(file):
    with open(file, "r") as tf:
        lines = tf.read().split('\n')
    return lines

# %%
def count_occurances(row, attributes):
    counter = 0
    for attribute in attributes:
        subcounter = str(row).count(str(attribute))
        counter += subcounter
    return counter

# %%
def getAtributes(predata):
    agency = load_list("a_agency.txt")
    communion = load_list("a_communion.txt")
    predata["agency"] = predata.apply(lambda row: count_occurances(str(row["title"]), agency), axis=1)
    predata["communion"] = predata.apply(lambda row: count_occurances(str(row["title"]), communion), axis=1)
    predata["agency_context"] = predata.apply(lambda row: count_occurances(str(row["content"]), agency), axis=1)
    predata["communion_context"] = predata.apply(lambda row: count_occurances(str(row["content"]), communion), axis=1)
    return predata

# %%
def getAll(predata):
    predata = convertURL(predata)
    predata = getSentiment(predata)
    predata = getLenght(predata)
    predata = getAtributes(predata)
    return predata

# %%
data = getAll(data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 data = getAll(data)
#
# Input In [48], in getAll(predata)
#       1 def getAll(predata):
# ----> 2     predata = convertURL(predata)
#       3     predata = getSentiment(predata)
#       4     predata = getLenght(predata)
#
# Input In [40], in convertURL(predata)
#       1 def convertURL(predata):
# ----> 2     predata["category"] = predata.apply(lambda row: str(row["article_url"]).split('/')[3] , axis=1)
#       3     predata["category"] = predata.apply(lambda row: findCategory(str(row["category"])) , axis=1)
#       4     return predata
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [40], in convertURL.<locals>.<lambda>(row)
#       1 def convertURL(predata):
# ----> 2     predata["category"] = predata.apply(lambda row: str(row["article_url"]).split('/')[3] , axis=1)
#       3     predata["category"] = predata.apply(lambda row: findCategory(str(row["category"])) , axis=1)
#       4     return predata
#
# IndexError: list index out of range

# %%
data

# %% [markdown]
# ## Datasets

# %%
compare = data
compare = compare.drop(columns=["article_url","title","published_date", "source", "type", "contents", "content", "merged_total_text", "entity","entity_type", "last_name", "agency", "communion"])
compare
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 compare = data
# ----> 2 compare = compare.drop(columns=["article_url","title","published_date", "source", "type", "contents", "content", "merged_total_text", "entity","entity_type", "last_name", "agency", "communion"])
#       3 compare
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['contents', 'merged_total_text', 'entity', 'entity_type', 'last_name'] not found in axis"

# %% [markdown]
# #### compare_author: Jeder einzige Artikel einmal ohne Personen im Text

# %%
compare_author = data
compare_author = compare_author .drop(columns=["article_url","published_date", "source", "type", "contents", "content", "merged_total_text", "entity","entity_type", "first_name", "last_name", "gender_guesser"])
compare_author = compare_author.drop_duplicates()

# %%
# Calculate percentange of gender (all articles)
gender_percentage = pd.DataFrame()
gender_percentage["gender_total_author"] = compare_author.groupby("gender_guesser_author")["id"].count()
gender_percentage["gender_percent_author"] = gender_percentage["gender_total_author"] / gender_percentage["gender_total_author"].sum() * 100
gender_percentage["gender_percent_author"] = gender_percentage["gender_percent_author"].astype(int)
gender_percentage
# Out:
#                        gender_total_author  gender_percent_author
# gender_guesser_author
# andy                                   529                      0
# female                               47813                     27
# male                                 88010                     50
# mostly_female                         2777                      1
# mostly_male                           4156                      2
# unknown                              31333                     17

# %% [markdown]
# Fast die Häfte der Artikel wurde von <font color='red'>Männern</font> geschrieben. Etwa ein Viertel der Artikel stammt von <font color='blue'>Frauen</font>.

# %%
unique_authors = compare_author
unique_authors = unique_authors.drop(columns=["id", "title", "len_title", "word_title", "title_vader_score"])
unique_authors = unique_authors.drop_duplicates()
unique_authors
# Out:
#         Unnamed: 0            author person_author gender_guesser_author  \
# 0                0    Mark Giannotto          Mark                  male
# 1                1    Mark Giannotto          Mark                  male
# 2                4    Mark Giannotto          Mark                  male
# 3                8    Mark Giannotto          Mark                  male
# 4                9    Mark Giannotto          Mark                  male
# ...            ...               ...           ...                   ...
# 174613      760782  Vanessa Williams       Vanessa                female
# 174614      760785  Vanessa Williams       Vanessa                female
# 174615      760787  Vanessa Williams       Vanessa                female
# 174616      760791  Vanessa Williams       Vanessa                female
# 174617      760792  Vanessa Williams       Vanessa                female
#
#                                                text   category  agency  \
# 0       <function createText at 0x000001E7CF406820>     sports       0
# 1       <function createText at 0x000001E7CF406820>     sports       0
# 2       <function createText at 0x000001E7CF406820>     sports       0
# 3       <function createText at 0x000001E7CF406820>     sports       0
# 4       <function createText at 0x000001E7CF406820>     sports       0
# ...                                             ...        ...     ...
# 174613  <function createText at 0x000001E7CF406820>  lifestyle       0
# 174614  <function createText at 0x000001E7CF406820>  lifestyle       0
# 174615  <function createText at 0x000001E7CF406820>  lifestyle       0
# 174616  <function createText at 0x000001E7CF406820>  lifestyle       0
# 174617  <function createText at 0x000001E7CF406820>  lifestyle       0
#
#         communion  agency_context  communion_context
# 0               1              33                 75
# 1               1              33                 75
# 2               1              33                 75
# 3               1              33                 75
# 4               1              33                 75
# ...           ...             ...                ...
# 174613          1              30                 57
# 174614          1              30                 57
# 174615          1              30                 57
# 174616          1              30                 57
# 174617          1              30                 57
#
# [174618 rows x 10 columns]

# %%
# Calculate percentange of gender (single authors)
gender_percentage = pd.DataFrame()
gender_percentage["gender_total_author"] = unique_authors.groupby("gender_guesser_author")["author"].count()
gender_percentage["gender_percent_author"] = gender_percentage["gender_total_author"] / gender_percentage["gender_total_author"].sum() * 100
gender_percentage["gender_percent_author"] = gender_percentage["gender_percent_author"].astype(int)
gender_percentage
# Out:
#                        gender_total_author  gender_percent_author
# gender_guesser_author
# andy                                   529                      0
# female                               47813                     27
# male                                 88010                     50
# mostly_female                         2777                      1
# mostly_male                           4156                      2
# unknown                              31333                     17

# %% [markdown]
# Die Autorenschaft besteht aus 30% aus <font color='blue'>Frauen</font>, 51% aus <font color='red'>Männern</font> und 11% <font color='green'>unknown</font>. Das deckt sich etwa mit den geschriebenen Artikeln insgesamt

# %%
not_quiet_unique_authors = compare_author
not_quiet_unique_authors = not_quiet_unique_authors.drop(columns=["id", "title"])
not_quiet_unique_authors = not_quiet_unique_authors.drop_duplicates()
not_quiet_unique_authors
# Out:
#         Unnamed: 0            author person_author gender_guesser_author  \
# 0                0    Mark Giannotto          Mark                  male
# 1                1    Mark Giannotto          Mark                  male
# 2                4    Mark Giannotto          Mark                  male
# 3                8    Mark Giannotto          Mark                  male
# 4                9    Mark Giannotto          Mark                  male
# ...            ...               ...           ...                   ...
# 174613      760782  Vanessa Williams       Vanessa                female
# 174614      760785  Vanessa Williams       Vanessa                female
# 174615      760787  Vanessa Williams       Vanessa                female
# 174616      760791  Vanessa Williams       Vanessa                female
# 174617      760792  Vanessa Williams       Vanessa                female
#
#                                                text   category  \
# 0       <function createText at 0x000001E7CF406820>     sports
# 1       <function createText at 0x000001E7CF406820>     sports
# 2       <function createText at 0x000001E7CF406820>     sports
# 3       <function createText at 0x000001E7CF406820>     sports
# 4       <function createText at 0x000001E7CF406820>     sports
# ...                                             ...        ...
# 174613  <function createText at 0x000001E7CF406820>  lifestyle
# 174614  <function createText at 0x000001E7CF406820>  lifestyle
# 174615  <function createText at 0x000001E7CF406820>  lifestyle
# 174616  <function createText at 0x000001E7CF406820>  lifestyle
# 174617  <function createText at 0x000001E7CF406820>  lifestyle
#
#        title_vader_score  word_title  len_title  agency  communion  \
# 0               Positive          13         69       0          1
# 1               Positive          13         69       0          1
# 2               Positive          13         69       0          1
# 3               Positive          13         69       0          1
# 4               Positive          13         69       0          1
# ...                  ...         ...        ...     ...        ...
# 174613           Neutral          18         91       0          1
# 174614           Neutral          18         91       0          1
# 174615           Neutral          18         91       0          1
# 174616           Neutral          18         91       0          1
# 174617           Neutral          18         91       0          1
#
#         agency_context  communion_context
# 0                   33                 75
# 1                   33                 75
# 2                   33                 75
# 3                   33                 75
# 4                   33                 75
# ...                ...                ...
# 174613              30                 57
# 174614              30                 57
# 174615              30                 57
# 174616              30                 57
# 174617              30                 57
#
# [174618 rows x 13 columns]

# %%
compare_persons = data
compare_persons = compare_persons.drop(columns=['id', 'article_url', 'title', 'author', 'published_date', 'contents',
       'type', 'source', 'content', 'merged_total_text', 'entity','entity_type', 'last_name', 
       ])
compare_persons = compare_persons.drop_duplicates()
compare_persons
# Out:
#         Unnamed: 0 first_name gender_guesser person_author  \
# 0                0      Danny           male          Mark
# 1                1    Jarrett           male          Mark
# 2                4      Danny           male          Mark
# 3                8    Jarrett           male          Mark
# 4                9       John           male          Mark
# ...            ...        ...            ...           ...
# 174613      760782    Abraham           male       Vanessa
# 174614      760785   Williams        unknown       Vanessa
# 174615      760787  Catherine         female       Vanessa
# 174616      760791   Williams        unknown       Vanessa
# 174617      760792   Williams        unknown       Vanessa
#
#        gender_guesser_author                                         text  \
# 0                       male  <function createText at 0x000001E7CF406820>
# 1                       male  <function createText at 0x000001E7CF406820>
# 2                       male  <function createText at 0x000001E7CF406820>
# 3                       male  <function createText at 0x000001E7CF406820>
# 4                       male  <function createText at 0x000001E7CF406820>
# ...                      ...                                          ...
# 174613                female  <function createText at 0x000001E7CF406820>
# 174614                female  <function createText at 0x000001E7CF406820>
# 174615                female  <function createText at 0x000001E7CF406820>
# 174616                female  <function createText at 0x000001E7CF406820>
# 174617                female  <function createText at 0x000001E7CF406820>
#
#          category title_vader_score  word_title  len_title  agency  communion  \
# 0          sports          Positive          13         69       0          1
# 1          sports          Positive          13         69       0          1
# 2          sports          Positive          13         69       0          1
# 3          sports          Positive          13         69       0          1
# 4          sports          Positive          13         69       0          1
# ...           ...               ...         ...        ...     ...        ...
# 174613  lifestyle           Neutral          18         91       0          1
# 174614  lifestyle           Neutral          18         91       0          1
# 174615  lifestyle           Neutral          18         91       0          1
# 174616  lifestyle           Neutral          18         91       0          1
# 174617  lifestyle           Neutral          18         91       0          1
#
#         agency_context  communion_context
# 0                   33                 75
# 1                   33                 75
# 2                   33                 75
# 3                   33                 75
# 4                   33                 75
# ...                ...                ...
# 174613              30                 57
# 174614              30                 57
# 174615              30                 57
# 174616              30                 57
# 174617              30                 57
#
# [174618 rows x 14 columns]

# %%
data.to_csv("data_to_use")
compare.to_csv("compare")
compare_author.to_csv("compare")
unique_authors.to_csv("unique_authors")
compare_persons.to_csv("compare_persons")

# %% [markdown]
# ## Comparing

# %%
def get_gendered_information(name, dataframe, focused_column, search_index):
    frame = pd.DataFrame()
    frame[str(name) + " total"] = dataframe.groupby(str(focused_column))[str(search_index)].count()
    frame[str(name) + " percent"] = frame[str(name) + " total"] / frame[str(name) + " total"].sum() * 100
    frame[str(name) + " percent"] = frame[str(name) + " percent"].astype(int)
    return frame

# %%
def combine_dataframes(dataframe1, dataframe2, dataframe3):
    frame = pd.DataFrame()
    frame = dataframe1.join(dataframe2, how='outer')
    frame = frame.join(dataframe3, how = 'outer')
    return frame

# %% [markdown]
# ### Comparing Authors

# %%
male_authors = compare_author[compare_author.gender_guesser_author == "male"] 
female_authors = compare_author[compare_author.gender_guesser_author == "female"]
unknown_authors = compare_author[compare_author.gender_guesser_author == "unknown"]

# %% [markdown]
# #### Category

# %%
author_male_category = get_gendered_information('male', male_authors, 'category', 'author')
author_female_category = get_gendered_information('female', female_authors, 'category', 'author')
author_unknown_category = get_gendered_information('unknown' , unknown_authors, 'category', 'author')

category_data = combine_dataframes(author_male_category, author_female_category, author_unknown_category)
category_data
# Out:
#                 male total  male percent  female total  female percent  \
# category
# 2010                   NaN           NaN           NaN             NaN
# 2012                  62.0           0.0           NaN             NaN
# business            4675.0           5.0        4995.0            10.0
# cars                  15.0           0.0           NaN             NaN
# conversations         12.0           0.0          44.0             0.0
# entertainment       6549.0           7.0        3403.0             7.0
# goingoutguide         85.0           0.0         509.0             1.0
# investigations       218.0           0.0         226.0             0.0
# jobs_articles          NaN           NaN           3.0             0.0
# kidspost               NaN           NaN          25.0             0.0
# lifestyle           9427.0          10.0       11059.0            23.0
# local              13342.0          15.0        8485.0            17.0
# national            2347.0           2.0        2749.0             5.0
# opinions            6438.0           7.0        2831.0             5.0
# other                476.0           0.0         333.0             0.0
# politics           14733.0          16.0        5326.0            11.0
# realestate           245.0           0.0         494.0             1.0
# sports             22065.0          25.0        4147.0             8.0
# world               7321.0           8.0        3184.0             6.0
#
#                 unknown total  unknown percent
# category
# 2010                       35                0
# 2012                       34                0
# business                 2030                6
# cars                        2                0
# conversations               3                0
# entertainment             705                2
# goingoutguide             158                0
# investigations              4                0
# jobs_articles              12                0
# kidspost                  106                0
# lifestyle                2545                8
# local                   12365               39
# national                  658                2
# opinions                 4589               14
# other                     488                1
# politics                 3097                9
# realestate                  8                0
# sports                   3295               10
# world                    1199                3

# %% [markdown]
# Die <font color='red'>männlichen</font> Autoren schreiben vor allem über <font color='red'>Sport, Lokales und Politik</font>. <font color='blue'>Weibliche Autoren</font> schreiben vor allem Artikel über <font color='blue'>Lifestyle, Lokales und Business</font>.

# %% [markdown]
# #### Sentiment

# %%
author_male_sentiment = get_gendered_information('male', male_authors, 'title_vader_score', 'author')
author_female_sentiment = get_gendered_information('female', female_authors, 'title_vader_score', 'author')
author_unknown_sentiment = get_gendered_information('unknown' , unknown_authors, 'title_vader_score', 'author')

sentiment_data = combine_dataframes(author_male_sentiment, author_female_sentiment, author_unknown_sentiment)
sentiment_data
# Out:
#                    male total  male percent  female total  female percent  \
# title_vader_score
# Negative                23226            26         11939              24
# Neutral                 39374            44         22391              46
# Positive                25410            28         13483              28
#
#                    unknown total  unknown percent
# title_vader_score
# Negative                    5860               18
# Neutral                    19070               60
# Positive                    6403               20

# %% [markdown]
# Der Title wird beinahme immer polarisierend geschrieben. Negative und positive ist daber gleichgewichtig. Auch im Hinblick auf das Geschlecht gibt es keine großen Auffälligkeiten.

# %% [markdown]
# #### Lenght

# %%
author_male_lenght_title = get_gendered_information('male', male_authors, 'word_title', 'author')
author_female_lenght_title = get_gendered_information('female', female_authors, 'word_title', 'author')
author_unknown_lenght_title = get_gendered_information('unknown' , unknown_authors, 'word_title', 'author')

lenght_data_title = combine_dataframes(author_male_lenght_title, author_female_lenght_title, author_unknown_lenght_title)
lenght_data_title
# Out:
#             male total  male percent  female total  female percent  \
# word_title
# 1                  6.0           0.0           NaN             NaN
# 2               1158.0           1.0        1225.0             2.0
# 3                184.0           0.0         190.0             0.0
# 4                574.0           0.0         724.0             1.0
# 5               1997.0           2.0        1479.0             3.0
# 6               4214.0           4.0        2439.0             5.0
# 7               6332.0           7.0        3694.0             7.0
# 8               7410.0           8.0        4454.0             9.0
# 9               9294.0          10.0        5163.0            10.0
# 10              8646.0           9.0        4948.0            10.0
# 11              9135.0          10.0        4687.0             9.0
# 12              9706.0          11.0        4288.0             8.0
# 13              7297.0           8.0        3313.0             6.0
# 14              6559.0           7.0        3209.0             6.0
# 15              5571.0           6.0        2518.0             5.0
# 16              3616.0           4.0        2043.0             4.0
# 17              2268.0           2.0        1069.0             2.0
# 18              1466.0           1.0         876.0             1.0
# 19               898.0           1.0         653.0             1.0
# 20               668.0           0.0         224.0             0.0
# 21               423.0           0.0         176.0             0.0
# 22               192.0           0.0         106.0             0.0
# 23                60.0           0.0          26.0             0.0
# 24                52.0           0.0          19.0             0.0
# 25               104.0           0.0          49.0             0.0
# 26                76.0           0.0         104.0             0.0
# 27                27.0           0.0          47.0             0.0
# 29                 NaN           NaN          21.0             0.0
# 35                 NaN           NaN          19.0             0.0
# 37                47.0           0.0          50.0             0.0
# 40                30.0           0.0           NaN             NaN
#
#             unknown total  unknown percent
# word_title
# 1                     8.0              0.0
# 2                  1340.0              4.0
# 3                   356.0              1.0
# 4                   909.0              2.0
# 5                  2258.0              7.0
# 6                  2151.0              6.0
# 7                  2420.0              7.0
# 8                  4499.0             14.0
# 9                  2078.0              6.0
# 10                 3543.0             11.0
# 11                 3272.0             10.0
# 12                 2327.0              7.0
# 13                 1729.0              5.0
# 14                 1445.0              4.0
# 15                 1059.0              3.0
# 16                  891.0              2.0
# 17                  328.0              1.0
# 18                  334.0              1.0
# 19                  114.0              0.0
# 20                   14.0              0.0
# 21                   35.0              0.0
# 22                  142.0              0.0
# 23                   20.0              0.0
# 24                    NaN              NaN
# 25                    NaN              NaN
# 26                   61.0              0.0
# 27                    NaN              NaN
# 29                    NaN              NaN
# 35                    NaN              NaN
# 37                    NaN              NaN
# 40                    NaN              NaN

# %% [markdown]
# #### agency - communion

# %%
author_male_agency = get_gendered_information('male', male_authors, 'agency_context', 'author')
author_female_agency = get_gendered_information('female', female_authors, 'agency_context', 'author')
author_unknown_agency = get_gendered_information('unknown' , unknown_authors, 'agency_context', 'author')

author__agency = combine_dataframes(author_male_agency, author_female_agency, author_unknown_agency)
author__agency
# Out:
#                 male total  male percent  female total  female percent  \
# agency_context
# 0                      NaN           NaN           2.0             0.0
# 1                     40.0           0.0          11.0             0.0
# 2                     60.0           0.0          28.0             0.0
# 3                     79.0           0.0          67.0             0.0
# 4                    112.0           0.0         141.0             0.0
# ...                    ...           ...           ...             ...
# 253                    NaN           NaN         283.0             0.0
# 259                  192.0           0.0           NaN             NaN
# 296                    NaN           NaN           4.0             0.0
# 373                    NaN           NaN           NaN             NaN
# 421                    NaN           NaN           NaN             NaN
#
#                 unknown total  unknown percent
# agency_context
# 0                       719.0              2.0
# 1                       940.0              3.0
# 2                       811.0              2.0
# 3                       940.0              3.0
# 4                       726.0              2.0
# ...                       ...              ...
# 253                       NaN              NaN
# 259                       NaN              NaN
# 296                       NaN              NaN
# 373                      34.0              0.0
# 421                      24.0              0.0
#
# [171 rows x 6 columns]

# %%
author_male_communion = get_gendered_information('male', male_authors, 'communion_context', 'author')
author_female_communion = get_gendered_information('female', female_authors, 'communion_context', 'author')
author_unknown_communion = get_gendered_information('unknown' , unknown_authors, 'communion_context', 'author')

author__communion = combine_dataframes(author_male_communion, author_female_communion, author_unknown_communion)
author__communion
# Out:
#                    male total  male percent  female total  female percent  \
# communion_context
# 0                         NaN           NaN           NaN             NaN
# 1                         NaN           NaN           NaN             NaN
# 2                         1.0           0.0           NaN             NaN
# 3                         9.0           0.0           8.0             0.0
# 4                        58.0           0.0           7.0             0.0
# ...                       ...           ...           ...             ...
# 360                     139.0           0.0           NaN             NaN
# 366                     168.0           0.0           NaN             NaN
# 488                       NaN           NaN           NaN             NaN
# 494                       NaN           NaN           NaN             NaN
# 571                       NaN           NaN           NaN             NaN
#
#                    unknown total  unknown percent
# communion_context
# 0                           36.0              0.0
# 1                          183.0              0.0
# 2                          279.0              0.0
# 3                          587.0              1.0
# 4                          528.0              1.0
# ...                          ...              ...
# 360                          NaN              NaN
# 366                          NaN              NaN
# 488                         24.0              0.0
# 494                          8.0              0.0
# 571                         34.0              0.0
#
# [196 rows x 6 columns]

# %%
author__communion['male percent'].max()
# Out:
# 2.0

# %%
author__communion['female percent'].max()
# Out:
# 2.0

# %%
author__communion['unknown percent'].max()
# Out:
# 2.0

# %%
sentiment_data.to_csv("sentiment_data")
lenght_data_title.to_csv("lenght_data_title")
category_data.to_csv("category_data")
author__agency.to_csv("author__agency")
author__communion.to_csv("author__communion")

# %% [markdown]
# ### Compare Person in Context

# %%
male_context = compare_persons[compare_persons.gender_guesser == "male"] 
female_context = compare_persons[compare_persons.gender_guesser == "female"]
unknown_context = compare_persons[compare_persons.gender_guesser == "unknown"]

# %% [markdown]
# #### category

# %%
context_author_male_category = get_gendered_information('male', male_context, 'category', 'first_name')
context_author_female_category = get_gendered_information('female', female_context, 'category', 'first_name')
context_author_unknown_category = get_gendered_information('unknown' , unknown_context, 'category', 'first_name')

context_category_data = combine_dataframes(context_author_male_category, context_author_female_category, context_author_unknown_category)
context_category_data
# Out:
#                 male total  male percent  female total  female percent  \
# category
# 2010                  17.0           0.0             9               0
# 2012                  27.0           0.0             9               0
# business            5239.0           7.0          1409               7
# cars                   8.0           0.0             3               0
# conversations         38.0           0.0             8               0
# entertainment       4273.0           5.0          1799               9
# goingoutguide        368.0           0.0           128               0
# investigations       140.0           0.0            30               0
# jobs_articles          NaN           NaN             6               0
# kidspost              46.0           0.0            25               0
# lifestyle           9331.0          12.0          4160              20
# local              14651.0          20.0          6415              32
# national            2402.0           3.0           739               3
# opinions            6257.0           8.0           648               3
# other                497.0           0.0           193               0
# politics           10949.0          14.0          1571               7
# realestate           313.0           0.0           140               0
# sports             13624.0          18.0          1679               8
# world               4923.0           6.0           945               4
#
#                 unknown total  unknown percent
# category
# 2010                        6                0
# 2012                       48                0
# business                 4708                6
# cars                        4                0
# conversations              23                0
# entertainment            4327                6
# goingoutguide             258                0
# investigations            246                0
# jobs_articles               9                0
# kidspost                   33                0
# lifestyle                9270               13
# local                   12448               17
# national                 2462                3
# opinions                 6488                9
# other                     557                0
# politics                10759               15
# realestate                278                0
# sports                  13643               19
# world                    5412                7

# %% [markdown]
# #### Sentiment

# %%
context_author_male_sentiment = get_gendered_information('male', male_context, 'title_vader_score', 'first_name')
context_author_female_sentiment = get_gendered_information('female', female_context, 'title_vader_score', 'first_name')
context_author_unknown_sentiment = get_gendered_information('unknown' , unknown_context, 'title_vader_score', 'first_name')

context_sentiment_data = combine_dataframes(context_author_male_sentiment, context_author_female_sentiment, context_author_unknown_sentiment)
context_sentiment_data
# Out:
#                    male total  male percent  female total  female percent  \
# title_vader_score
# Negative                18136            24          4092              20
# Neutral                 35192            48         10819              54
# Positive                19775            27          5005              25
#
#                    unknown total  unknown percent
# title_vader_score
# Negative                   18600               26
# Neutral                    32524               45
# Positive                   19855               27

# %% [markdown]
# #### lenght

# %%
context_male_lenght_title = get_gendered_information('male', male_context, 'word_title', 'first_name')
context_female_lenght_title = get_gendered_information('female', female_context, 'word_title', 'first_name')
context_unknown_lenght_title = get_gendered_information('unknown' , unknown_context, 'word_title', 'first_name')

context_lenght_data_title = combine_dataframes(context_male_lenght_title, context_female_lenght_title, context_unknown_lenght_title)
context_lenght_data_title
# Out:
#             male total  male percent  female total  female percent  \
# word_title
# 1                    5             0             1               0
# 2                 1643             2           606               3
# 3                  333             0           111               0
# 4                  926             1           348               1
# 5                 2505             3           928               4
# 6                 4004             5          1111               5
# 7                 5387             7          1445               7
# 8                 7228             9          2280              11
# 9                 7492            10          1662               8
# 10                7645            10          2166              10
# 11                7409            10          1984               9
# 12                6831             9          1865               9
# 13                5218             7          1166               5
# 14                4604             6          1332               6
# 15                4154             5           961               4
# 16                2869             3           731               3
# 17                1578             2           403               2
# 18                1252             1           309               1
# 19                 738             1           184               0
# 20                 391             0            63               0
# 21                 264             0            80               0
# 22                 263             0            70               0
# 23                 112             0            30               0
# 24                  43             0             2               0
# 25                  56             0            16               0
# 26                  93             0            41               0
# 27                   8             0             8               0
# 29                   1             0             5               0
# 35                   5             0             1               0
# 37                  31             0             1               0
# 40                  15             0             6               0
#
#             unknown total  unknown percent
# word_title
# 1                       7                0
# 2                    1354                1
# 3                     249                0
# 4                     833                1
# 5                    2024                2
# 6                    3652                5
# 7                    5286                7
# 8                    6120                8
# 9                    7229               10
# 10                   6937                9
# 11                   7276               10
# 12                   7302               10
# 13                   5565                7
# 14                   5133                7
# 15                   4022                5
# 16                   2942                4
# 17                   1682                2
# 18                   1183                1
# 19                    669                0
# 20                    425                0
# 21                    317                0
# 22                    209                0
# 23                    198                0
# 24                     35                0
# 25                     80                0
# 26                    100                0
# 27                     57                0
# 29                     15                0
# 35                      7                0
# 37                     62                0
# 40                      9                0

# %% [markdown]
# #### Gender of Author (werden männliche Personen häufiger von Männern erwähnt etc)

# %%
context_male_author_gender = get_gendered_information('male', male_context, 'gender_guesser_author', 'first_name')
context_female_author_gender = get_gendered_information('female', female_context, 'gender_guesser_author', 'first_name')
context_unknown_author_gender = get_gendered_information('unknown' , unknown_context, 'gender_guesser_author', 'first_name')

context_gender_data = combine_dataframes(context_male_author_gender, context_female_author_gender, context_unknown_author_gender)
context_gender_data
# Out:
#                        male total  male percent  female total  female percent  \
# gender_guesser_author
# andy                          283             0            50               0
# female                      19235            26          6475              32
# male                        37573            51          6390              32
# mostly_female                 981             1           417               2
# mostly_male                  1484             2           509               2
# unknown                     13547            18          6075              30
#
#                        unknown total  unknown percent
# gender_guesser_author
# andy                             153                0
# female                         19384               27
# male                           38807               54
# mostly_female                   1163                1
# mostly_male                     1942                2
# unknown                         9530               13

# %% [markdown]
# <font color='red'>Männliche Autoren</font> schreiben doppelt so oft über <font color='red'>Männer</font>.
# <font color='blue'>Weibliche Autoren</font> schreiben ausgeglichener über beide Geschlechter.

# %% [markdown]
# #### agency-communion

# %%
context_male_agency = get_gendered_information('male', male_context, 'agency', 'first_name')
context_female_agency = get_gendered_information('female', female_context, 'agency', 'first_name')
context_unknown_agency = get_gendered_information('unknown' , unknown_context, 'agency', 'first_name')

context__agency = combine_dataframes(context_male_agency, context_female_agency, context_unknown_agency)
context__agency
# Out:
#         male total  male percent  female total  female percent  unknown total  \
# agency
# 0            52842            72       15096.0            75.0        50701.0
# 1            14572            19        3655.0            18.0        14426.0
# 2             4439             6         957.0             4.0         4690.0
# 3             1008             1         161.0             0.0          963.0
# 4              215             0          46.0             0.0          183.0
# 5               26             0           1.0             0.0           16.0
# 8                1             0           NaN             NaN            NaN
#
#         unknown percent
# agency
# 0                  71.0
# 1                  20.0
# 2                   6.0
# 3                   1.0
# 4                   0.0
# 5                   0.0
# 8                   NaN

# %%
context_male_communion = get_gendered_information('male', male_context, 'communion', 'first_name')
context_female_communion = get_gendered_information('female', female_context, 'communion', 'first_name')
context_unknown_communion = get_gendered_information('unknown' , unknown_context, 'communion', 'first_name')

context__communion = combine_dataframes(context_male_communion, context_female_communion, context_unknown_communion)
context__communion
# Out:
#            male total  male percent  female total  female percent  \
# communion
# 0               49553            67       13712.0            68.0
# 1               19394            26        5126.0            25.0
# 2                3342             4         903.0             4.0
# 3                 767             1         169.0             0.0
# 4                  46             0           6.0             0.0
# 5                   1             0           NaN             NaN
#
#            unknown total  unknown percent
# communion
# 0                47664.0             67.0
# 1                18854.0             26.0
# 2                 3580.0              5.0
# 3                  817.0              1.0
# 4                   64.0              0.0
# 5                    NaN              NaN

# %%
context_sentiment_data.to_csv("context_sentiment_data")
context_lenght_data_title.to_csv("context_lenght_data_title")
context_category_data.to_csv("context_category_data")
context_gender_data.to_csv("context_gender_data")
context__agency.to_csv("context__agency")
context__communion.to_csv("context__communion")

# %% [markdown]
# <b>Erste Erkenntnisse, die wir für eine Prediction nutzen können:
# <li>Es werden fast doppelt so viele Artikel von Männern geschrieben als von Frauen</li>
# <li>Die Autorenschaft besteht aus 30% aus Frauen, 51% aus Männern und 11% unknown</li>
# <li>Ein großer Teil der Texte sind unknown (Nur Buchstaben als Vornahmen, ohne Autor etc.)</li>
# <li>Männer schreiben eher über sport und politics</li>
# <li>Frauen schreiben eher über lifestyle, business</li>
# <li>Lokal beide etwa gleich viel</li>
# <li>unknown vor allem opinions </li>
# <li>Es werden doppelt so viele Männer in Texten erwähnt als Frauen</li>
# <li>Frauen schreiben etwa gleichgewichtet über Männer und Frauen</li>
# <li>Männer und unknown schreiben deutlich mehr über Männer (zu 25% mehr)</li>
# <li>Besonders häufig werden Männer in der Kategorie sports erwähnt</li>
# <li>Besonders häufig werden Frauen in Lifestyle und Local erwähnt</li>
# <li>In Politik werden männer und Frauen etwa gleichhäufig besprochen</li>
#
# <li>Männer schreiben mit mehr agency Wörtern</li>
# <li>Frauen schreiben mit mehr communion Wörtern</li>
#
# <li>Männer werden häufiger durch agency Wörter beschrieben</li>
# <li>Frauen werden mit mehr communion Wörtern beschrieben</li>
#
# <li>Der Sentiment des Titels kann keinen Rückschluss auf das Autoren-Geschlecht bieten</li>
#
# <b>Fragen, die offen sind:
# <li>Kann der Sentiment des Titels Rückschluss auf die Geschlechter, über die gesprochen wird, bieten?</li>
# <li>Kann der Sentiment des Contents Rückschluss auf die Geschlechter, über die gesprochen wird, bieten?</li>
# <li>Kann der Sentiment des Titels Rückschluss auf das Autoren-Geschlecht bieten?</li>
#
# <b>Annahme, die noch zu prüfen sind:
# <li>Die Länge des Titels gibt keine Rückschlüsse auf das Geschlecht</li>
# <li>Die Länge des Textes gibt Rückschlüsse auf das Geschlecht (Männer bekommen mehr Platz?)</li>
# <li>Die Anzahl der Artikel, die von Frauen geschrieben wurden, haben mit der Zeit prozentual zugenommen</li>
# <li>Die Anzahl der Artikel, die über Frauen geschrieben wurden, haben mit der Zeit prozentual zugenommen</li>
